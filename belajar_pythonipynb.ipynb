# %%
print('hello world')
nama ='apta'
kelas = 2
print('nama saya' + nama + 'kelas' + str(kelas))

input_nama =input('masukan nama anda ')
print('nama anda = ' + input_nama)
input_umur =input('brp umur anda ')
print('umur anda = ' +input_umur)

#operasi matematika + - * /


saldo =input('masukan saldo awal > ')
deposit =input('ingin deposir brp > ')
hasil =int(saldo) + int(deposit)
print('saldo anda '+ saldo + ' deposit dengan '+ deposit +' = ' + str(hasil))

#if syntax

jumlah = 1
if jumlah ==2:
  print('mantap')
elif jumlah < 2:
    print('kocak')
else:
      print('coba lagi')

#array

pacar =['christy' , 'freya' , 'lily']
print(pacar)
print(pacar[2])



print(len(pacar))

#for loopig

for saya in pacar:
  print(saya)

print('permainan akan dimulai ')
awal =input('masukan saldo anda')
if awal >=str(20):
  print('silahkan bermain')
elif awal <str(20):
  print('saldo tidak mencukupi')
else:
  print('tidak dapat diterima')
# Out:
# hello world
# nama sayaaptakelas2
# masukan nama anda aigi
# nama anda = aigi
# brp umur anda 12
# umur anda = 12
# masukan saldo awal > 13
# ingin deposir brp > 13
# saldo anda 13 deposit dengan 13 = 26
# kocak
# ['christy', 'freya', 'lily']
# lily
# 3
# christy
# freya
# lily
# permainan akan dimulai
# masukan saldo anda30
# silahkan bermain
